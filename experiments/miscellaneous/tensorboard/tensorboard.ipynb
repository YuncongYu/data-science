# %% [markdown]
# # Tensorboard Example

# %%
# %env XLA_FLAGS=--xla_gpu_cuda_data_dir=/home/yu/anaconda3/envs/tf/lib
# !echo $XLA_FLAGS

# %%
import tensorflow as tf

tf.config.list_physical_devices()
# Out:
# 2023-03-20 16:10:09.603265: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-20 16:10:11.067679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-20 16:10:11.117338: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-20 16:10:11.117522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import time
from pathlib import Path

root_logdir = Path().absolute() / "logs"

% load_ext tensorboard
% tensorboard --logdir=./ logs --port=6006
# Out:
# Launching TensorBoard...

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

x_train = x_train[:10_000]
y_train = y_train[:10_000]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
log_dir = root_logdir / time.strftime("run_%Y_%m_%d-%H_%M_%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir, histogram_freq=1)

model = tf.keras.models.Sequential(
    [
        tf.keras.layers.Flatten(input_shape=(28, 28), name="layers_flatten"),
        tf.keras.layers.Dense(512, activation="relu", name="layers_dense"),
        tf.keras.layers.Dropout(0.2, name="layers_dropout"),
        tf.keras.layers.Dense(10, activation="softmax", name="layers_dense_2"),
    ]
)
model.compile(
    optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layers_flatten (Flatten)    (None, 784)               0
#
#  layers_dense (Dense)        (None, 512)               401920
#
#  layers_dropout (Dropout)    (None, 512)               0
#
#  layers_dense_2 (Dense)      (None, 10)                5130
#
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# 2023-03-20 16:10:15.373050: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-20 16:10:15.373557: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-20 16:10:15.373787: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-20 16:10:15.373922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-20 16:10:15.892206: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-20 16:10:15.892549: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-20 16:10:15.892708: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-20 16:10:15.892848: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3285 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
history = model.fit(
    x=x_train,
    y=y_train,
    epochs=5,
    validation_data=(x_test, y_test),
    batch_size=32,
    callbacks=[tensorboard_callback],
)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4457 - accuracy: 0.8707 - val_loss: 0.2426 - val_accuracy: 0.9293
# Epoch 2/5
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2020 - accuracy: 0.9411 - val_loss: 0.1957 - val_accuracy: 0.9408
# Epoch 3/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1348 - accuracy: 0.9608 - val_loss: 0.1763 - val_accuracy: 0.9463
# Epoch 4/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0961 - accuracy: 0.9720 - val_loss: 0.1795 - val_accuracy: 0.9440
# Epoch 5/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0680 - accuracy: 0.9803 - val_loss: 0.1582 - val_accuracy: 0.9525
