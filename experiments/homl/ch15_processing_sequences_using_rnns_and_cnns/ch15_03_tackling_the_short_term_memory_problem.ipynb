# %% [markdown]
# # LSTM

# %% [markdown]
# ## 1 Data

# %%
from load_data import load_data

dataset = load_data()
# Out:
# single_step :
#    X :
#      train :  (7000, 41, 1)
#      valid :  (2000, 41, 1)
#      test :  (1000, 41, 1)
#    Y :
#      train :  (7000, 41, 10)
#      valid :  (2000, 41, 10)
#      test :  (1000, 41, 10)
# multi_horizon :
#    X :
#      train :  (7000, 41, 1)
#      valid :  (2000, 41, 1)
#      test :  (1000, 41, 1)
#    Y :
#      train :  (7000, 41, 10)
#      valid :  (2000, 41, 10)
#      test :  (1000, 41, 10)
# sequence :
#    X :
#      train :  (7000, 41, 1)
#      valid :  (2000, 41, 1)
#      test :  (1000, 41, 1)
#    Y :
#      train :  (7000, 41, 10)
#      valid :  (2000, 41, 10)
#      test :  (1000, 41, 10)

# %% [markdown]
# ## 2 Model

# %% [markdown]
# ### 2.1 Layer

# %%
None

# %% [markdown]
# ### 2.2 Model

# %%
import tensorflow as tf

def mse_last_time_step(y_true: tf.Tensor, y_pred: tf.Tensor) -> tf.Tensor:
    return tf.keras.metrics.mean_squared_error(y_true[:, -1], y_pred[:, -1])
# Out:
# 2023-02-06 05:57:30.845044: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(20, return_sequences=True, input_shape=(None, 1)),
    tf.keras.layers.LSTM(20, return_sequences=True),
    tf.keras.layers.Dense(10)
])
model.compile(optimizer="adam", loss="mse", metrics=mse_last_time_step)
model.summary()
# Out:
# 2023-02-06 05:57:34.224891: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 05:57:34.288602: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 05:57:34.288908: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 05:57:34.289793: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-06 05:57:34.290413: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 05:57:34.290691: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 05:57:34.290946: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 05:57:35.115454: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 05:57:35.115763: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 05:57:35.116019: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 05:57:35.116305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2714 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, None, 20)          1760
#
#  lstm_1 (LSTM)               (None, None, 20)          3280
#
#  dense (Dense)               (None, None, 10)          210
#
# =================================================================
# Total params: 5,250
# Trainable params: 5,250
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3 Training

# %%
import time
from pathlib import Path

epochs = 100
root_logdir = Path().absolute() / "logs"
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
tensorboard_cb = tf.keras.callbacks.TensorBoard(root_logdir / time.strftime("%Y_%m_%d-%H_%M_%S_rnn_sts"))

# %load_ext tensorboard
# %tensorboard --logdir=./logs --port=6006
# Out:
# Launching TensorBoard...

# %%
history = model.fit(dataset["sequence"]["X"]["train"], dataset["sequence"]["Y"]["train"], validation_data=(dataset["sequence"]["X"]["valid"], dataset["sequence"]["Y"]["valid"]), epochs=epochs, callbacks=[early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/100
# 2023-02-06 05:57:42.120689: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 219/219 [==============================] - 5s 10ms/step - loss: 0.0665 - mse_last_time_step: 0.0626 - val_loss: 0.0411 - val_mse_last_time_step: 0.0382
# Epoch 2/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0356 - mse_last_time_step: 0.0308 - val_loss: 0.0316 - val_mse_last_time_step: 0.0259
# Epoch 3/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0263 - mse_last_time_step: 0.0176 - val_loss: 0.0220 - val_mse_last_time_step: 0.0114
# Epoch 4/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0201 - mse_last_time_step: 0.0097 - val_loss: 0.0199 - val_mse_last_time_step: 0.0116
# Epoch 5/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0180 - mse_last_time_step: 0.0082 - val_loss: 0.0175 - val_mse_last_time_step: 0.0084
# Epoch 6/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0166 - mse_last_time_step: 0.0071 - val_loss: 0.0160 - val_mse_last_time_step: 0.0074
# Epoch 7/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0156 - mse_last_time_step: 0.0068 - val_loss: 0.0150 - val_mse_last_time_step: 0.0065
# Epoch 8/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0147 - mse_last_time_step: 0.0064 - val_loss: 0.0144 - val_mse_last_time_step: 0.0064
# Epoch 9/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0140 - mse_last_time_step: 0.0061 - val_loss: 0.0136 - val_mse_last_time_step: 0.0060
# Epoch 10/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0135 - mse_last_time_step: 0.0059 - val_loss: 0.0129 - val_mse_last_time_step: 0.0057
# Epoch 11/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0130 - mse_last_time_step: 0.0058 - val_loss: 0.0125 - val_mse_last_time_step: 0.0058
# Epoch 12/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0124 - mse_last_time_step: 0.0055 - val_loss: 0.0121 - val_mse_last_time_step: 0.0054
# Epoch 13/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0121 - mse_last_time_step: 0.0054 - val_loss: 0.0117 - val_mse_last_time_step: 0.0055
# Epoch 14/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0117 - mse_last_time_step: 0.0053 - val_loss: 0.0114 - val_mse_last_time_step: 0.0052
# Epoch 15/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0113 - mse_last_time_step: 0.0051 - val_loss: 0.0111 - val_mse_last_time_step: 0.0050
# Epoch 16/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0111 - mse_last_time_step: 0.0050 - val_loss: 0.0110 - val_mse_last_time_step: 0.0054
# Epoch 17/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0108 - mse_last_time_step: 0.0049 - val_loss: 0.0106 - val_mse_last_time_step: 0.0052
# Epoch 18/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0106 - mse_last_time_step: 0.0049 - val_loss: 0.0104 - val_mse_last_time_step: 0.0049
# Epoch 19/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0103 - mse_last_time_step: 0.0047 - val_loss: 0.0100 - val_mse_last_time_step: 0.0046
# Epoch 20/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0102 - mse_last_time_step: 0.0048 - val_loss: 0.0100 - val_mse_last_time_step: 0.0050
# Epoch 21/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0099 - mse_last_time_step: 0.0046 - val_loss: 0.0098 - val_mse_last_time_step: 0.0048
# Epoch 22/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0098 - mse_last_time_step: 0.0045 - val_loss: 0.0096 - val_mse_last_time_step: 0.0045
# Epoch 23/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0096 - mse_last_time_step: 0.0045 - val_loss: 0.0093 - val_mse_last_time_step: 0.0043
# Epoch 24/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0095 - mse_last_time_step: 0.0043 - val_loss: 0.0092 - val_mse_last_time_step: 0.0041
# Epoch 25/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0093 - mse_last_time_step: 0.0042 - val_loss: 0.0094 - val_mse_last_time_step: 0.0044
# Epoch 26/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0092 - mse_last_time_step: 0.0042 - val_loss: 0.0091 - val_mse_last_time_step: 0.0043
# Epoch 27/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0091 - mse_last_time_step: 0.0042 - val_loss: 0.0092 - val_mse_last_time_step: 0.0044
# Epoch 28/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0090 - mse_last_time_step: 0.0041 - val_loss: 0.0089 - val_mse_last_time_step: 0.0041
# Epoch 29/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0089 - mse_last_time_step: 0.0041 - val_loss: 0.0089 - val_mse_last_time_step: 0.0041
# Epoch 30/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0088 - mse_last_time_step: 0.0039 - val_loss: 0.0088 - val_mse_last_time_step: 0.0042
# Epoch 31/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0087 - mse_last_time_step: 0.0038 - val_loss: 0.0086 - val_mse_last_time_step: 0.0040
# Epoch 32/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0086 - mse_last_time_step: 0.0038 - val_loss: 0.0087 - val_mse_last_time_step: 0.0040
# Epoch 33/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0086 - mse_last_time_step: 0.0037 - val_loss: 0.0085 - val_mse_last_time_step: 0.0039
# Epoch 34/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0085 - mse_last_time_step: 0.0038 - val_loss: 0.0083 - val_mse_last_time_step: 0.0036
# Epoch 35/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0084 - mse_last_time_step: 0.0036 - val_loss: 0.0082 - val_mse_last_time_step: 0.0035
# Epoch 36/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0084 - mse_last_time_step: 0.0036 - val_loss: 0.0082 - val_mse_last_time_step: 0.0035
# Epoch 37/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0083 - mse_last_time_step: 0.0035 - val_loss: 0.0081 - val_mse_last_time_step: 0.0034
# Epoch 38/100
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0083 - mse_last_time_step: 0.0035 - val_loss: 0.0081 - val_mse_last_time_step: 0.0036
# Epoch 39/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0082 - mse_last_time_step: 0.0034 - val_loss: 0.0081 - val_mse_last_time_step: 0.0034
# Epoch 40/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0081 - mse_last_time_step: 0.0033 - val_loss: 0.0079 - val_mse_last_time_step: 0.0032
# Epoch 41/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0081 - mse_last_time_step: 0.0034 - val_loss: 0.0080 - val_mse_last_time_step: 0.0034
# Epoch 42/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0080 - mse_last_time_step: 0.0033 - val_loss: 0.0078 - val_mse_last_time_step: 0.0032
# Epoch 43/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0080 - mse_last_time_step: 0.0032 - val_loss: 0.0080 - val_mse_last_time_step: 0.0032
# Epoch 44/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0080 - mse_last_time_step: 0.0032 - val_loss: 0.0079 - val_mse_last_time_step: 0.0033
# Epoch 45/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0079 - mse_last_time_step: 0.0032 - val_loss: 0.0078 - val_mse_last_time_step: 0.0032
# Epoch 46/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0079 - mse_last_time_step: 0.0032 - val_loss: 0.0078 - val_mse_last_time_step: 0.0032
# Epoch 47/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0079 - mse_last_time_step: 0.0031 - val_loss: 0.0077 - val_mse_last_time_step: 0.0032
# Epoch 48/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0078 - mse_last_time_step: 0.0030 - val_loss: 0.0077 - val_mse_last_time_step: 0.0031
# Epoch 49/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0078 - mse_last_time_step: 0.0030 - val_loss: 0.0080 - val_mse_last_time_step: 0.0040
# Epoch 50/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0077 - mse_last_time_step: 0.0030 - val_loss: 0.0076 - val_mse_last_time_step: 0.0028
# Epoch 51/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0077 - mse_last_time_step: 0.0029 - val_loss: 0.0077 - val_mse_last_time_step: 0.0030
# Epoch 52/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0077 - mse_last_time_step: 0.0029 - val_loss: 0.0075 - val_mse_last_time_step: 0.0027
# Epoch 53/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0076 - mse_last_time_step: 0.0028 - val_loss: 0.0075 - val_mse_last_time_step: 0.0027
# Epoch 54/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0076 - mse_last_time_step: 0.0029 - val_loss: 0.0074 - val_mse_last_time_step: 0.0026
# Epoch 55/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0076 - mse_last_time_step: 0.0027 - val_loss: 0.0077 - val_mse_last_time_step: 0.0029
# Epoch 56/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0075 - mse_last_time_step: 0.0027 - val_loss: 0.0074 - val_mse_last_time_step: 0.0026
# Epoch 57/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0075 - mse_last_time_step: 0.0027 - val_loss: 0.0076 - val_mse_last_time_step: 0.0028
# Epoch 58/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0075 - mse_last_time_step: 0.0027 - val_loss: 0.0074 - val_mse_last_time_step: 0.0025
# Epoch 59/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0075 - mse_last_time_step: 0.0026 - val_loss: 0.0073 - val_mse_last_time_step: 0.0026
# Epoch 60/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0074 - mse_last_time_step: 0.0026 - val_loss: 0.0075 - val_mse_last_time_step: 0.0028
# Epoch 61/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0074 - mse_last_time_step: 0.0026 - val_loss: 0.0073 - val_mse_last_time_step: 0.0027
# Epoch 62/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0074 - mse_last_time_step: 0.0025 - val_loss: 0.0072 - val_mse_last_time_step: 0.0024
# Epoch 63/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0074 - mse_last_time_step: 0.0026 - val_loss: 0.0072 - val_mse_last_time_step: 0.0025
# Epoch 64/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0074 - mse_last_time_step: 0.0026 - val_loss: 0.0073 - val_mse_last_time_step: 0.0025
# Epoch 65/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0073 - mse_last_time_step: 0.0025 - val_loss: 0.0072 - val_mse_last_time_step: 0.0024
# Epoch 66/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0073 - mse_last_time_step: 0.0025 - val_loss: 0.0072 - val_mse_last_time_step: 0.0025
# Epoch 67/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0073 - mse_last_time_step: 0.0025 - val_loss: 0.0072 - val_mse_last_time_step: 0.0025
# Epoch 68/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0073 - mse_last_time_step: 0.0024 - val_loss: 0.0073 - val_mse_last_time_step: 0.0024
# Epoch 69/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0073 - mse_last_time_step: 0.0024 - val_loss: 0.0072 - val_mse_last_time_step: 0.0023
# Epoch 70/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0073 - mse_last_time_step: 0.0024 - val_loss: 0.0072 - val_mse_last_time_step: 0.0025
# Epoch 71/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0072 - mse_last_time_step: 0.0023 - val_loss: 0.0072 - val_mse_last_time_step: 0.0023
# Epoch 72/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0073 - mse_last_time_step: 0.0024 - val_loss: 0.0071 - val_mse_last_time_step: 0.0023
# Epoch 73/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0072 - mse_last_time_step: 0.0023 - val_loss: 0.0071 - val_mse_last_time_step: 0.0022
# Epoch 74/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0072 - mse_last_time_step: 0.0023 - val_loss: 0.0072 - val_mse_last_time_step: 0.0025
# Epoch 75/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0072 - mse_last_time_step: 0.0024 - val_loss: 0.0070 - val_mse_last_time_step: 0.0022
# Epoch 76/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0072 - mse_last_time_step: 0.0023 - val_loss: 0.0070 - val_mse_last_time_step: 0.0022
# Epoch 77/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0072 - mse_last_time_step: 0.0023 - val_loss: 0.0070 - val_mse_last_time_step: 0.0022
# Epoch 78/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0072 - mse_last_time_step: 0.0023 - val_loss: 0.0070 - val_mse_last_time_step: 0.0023
# Epoch 79/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0072 - mse_last_time_step: 0.0022 - val_loss: 0.0071 - val_mse_last_time_step: 0.0023
# Epoch 80/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0072 - mse_last_time_step: 0.0023 - val_loss: 0.0072 - val_mse_last_time_step: 0.0025
# Epoch 81/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0071 - mse_last_time_step: 0.0022 - val_loss: 0.0071 - val_mse_last_time_step: 0.0024
# Epoch 82/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0072 - mse_last_time_step: 0.0022 - val_loss: 0.0070 - val_mse_last_time_step: 0.0021
# Epoch 83/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0071 - mse_last_time_step: 0.0022 - val_loss: 0.0071 - val_mse_last_time_step: 0.0021
# Epoch 84/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0071 - mse_last_time_step: 0.0021 - val_loss: 0.0070 - val_mse_last_time_step: 0.0021
# Epoch 85/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0071 - mse_last_time_step: 0.0022 - val_loss: 0.0070 - val_mse_last_time_step: 0.0022
# Epoch 86/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0071 - mse_last_time_step: 0.0021 - val_loss: 0.0070 - val_mse_last_time_step: 0.0022
# Epoch 87/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0071 - mse_last_time_step: 0.0021 - val_loss: 0.0069 - val_mse_last_time_step: 0.0021
# Epoch 88/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0071 - mse_last_time_step: 0.0021 - val_loss: 0.0069 - val_mse_last_time_step: 0.0020
# Epoch 89/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0071 - mse_last_time_step: 0.0022 - val_loss: 0.0070 - val_mse_last_time_step: 0.0020
# Epoch 90/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0070 - mse_last_time_step: 0.0021 - val_loss: 0.0070 - val_mse_last_time_step: 0.0022
# Epoch 91/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0071 - mse_last_time_step: 0.0021 - val_loss: 0.0069 - val_mse_last_time_step: 0.0020
# Epoch 92/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0070 - mse_last_time_step: 0.0021 - val_loss: 0.0069 - val_mse_last_time_step: 0.0020
# Epoch 93/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0070 - mse_last_time_step: 0.0020 - val_loss: 0.0070 - val_mse_last_time_step: 0.0020
# Epoch 94/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0070 - mse_last_time_step: 0.0020 - val_loss: 0.0070 - val_mse_last_time_step: 0.0022
# Epoch 95/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0070 - mse_last_time_step: 0.0020 - val_loss: 0.0069 - val_mse_last_time_step: 0.0020
# Epoch 96/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0070 - mse_last_time_step: 0.0020 - val_loss: 0.0071 - val_mse_last_time_step: 0.0022
# Epoch 97/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0070 - mse_last_time_step: 0.0020 - val_loss: 0.0068 - val_mse_last_time_step: 0.0019
# Epoch 98/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0070 - mse_last_time_step: 0.0021 - val_loss: 0.0069 - val_mse_last_time_step: 0.0022
# Epoch 99/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0070 - mse_last_time_step: 0.0020 - val_loss: 0.0068 - val_mse_last_time_step: 0.0019
# Epoch 100/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0070 - mse_last_time_step: 0.0020 - val_loss: 0.0069 - val_mse_last_time_step: 0.0022

# %%
# Save model
dir_models = Path() / "models"
model.save(dir_models / "model_lstm")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/model_lstm/assets
# INFO:tensorflow:Assets written to: models/model_lstm/assets

# %% [markdown]
# ## 4 Evaluation

# %%
import numpy as np

i_ts = 1
x = dataset["sequence"]["X"]["test"][i_ts, :]
y_true = dataset["sequence"]["Y"]["test"][i_ts][-1, :]
y_pred = model.predict(x[np.newaxis, :, :])[0, -1]
# Out:
# 1/1 [==============================] - 1s 637ms/step

# %%
from plot import plot

plot(series=x[:, 0], y_true=y_true, y_pred=y_pred)
