# %% [markdown]
# # Section 1: Using TensorFlow like NumPy

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## 1.1 Tensors and Operations

# %% [markdown]
# Scaler

# %%
tf.constant(42)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=42>

# %% [markdown]
# Matrix

# %%
t = tf.constant([[1.0, 2, 3], [4, 5, 6]])
t
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[1., 2., 3.],
#        [4., 5., 6.]], dtype=float32)>

# %% [markdown]
# Shape and data type

# %%
t.shape
# Out:
# TensorShape([2, 3])

# %%
t.dtype
# Out:
# tf.float32

# %% [markdown]
# Indexing

# %%
t[:, 1:]
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[2., 3.],
#        [5., 6.]], dtype=float32)>

# %%
t[..., 1]
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([2., 5.], dtype=float32)>

# %%
t[..., 1, tf.newaxis]
# Out:
# <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[2.],
#        [5.]], dtype=float32)>

# %%
t[..., tf.newaxis, 1]
# Out:
# <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[2.],
#        [5.]], dtype=float32)>

# %%
t[tf.newaxis, ..., 1]
# Out:
# <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[2., 5.]], dtype=float32)>

# %%
t[..., 1, tf.newaxis, tf.newaxis]
# Out:
# <tf.Tensor: shape=(2, 1, 1), dtype=float32, numpy=
# array([[[2.]],
#
#        [[5.]]], dtype=float32)>

# %% [markdown]
# Tensor operations

# %%
t * t
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 1.,  4.,  9.],
#        [16., 25., 36.]], dtype=float32)>

# %%
t_t = tf.transpose(t)
t_t
# Out:
# <tf.Tensor: shape=(3, 2), dtype=float32, numpy=
# array([[1., 4.],
#        [2., 5.],
#        [3., 6.]], dtype=float32)>

# %%
t @ t_t
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[14., 32.],
#        [32., 77.]], dtype=float32)>

# %%
m = np.arange(1, 7).reshape(2, 3)
m
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
m @ m.T
# Out:
# array([[14, 32],
#        [32, 77]])

# %%
a = [[1, 2, 3], [4, 5, 6]]
a
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
b = list(zip(*a))
b
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %%
# Error unsupported operand type
# a @ b

# %% [markdown]
# Math operations

# %%
tf.reduce_mean(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.5>

# %% [markdown]
# Keras' low-level API

# %%
import tensorflow.keras.backend as K

K.square(K.transpose(t))
# Out:
# <tf.Tensor: shape=(3, 2), dtype=float32, numpy=
# array([[ 1., 16.],
#        [ 4., 25.],
#        [ 9., 36.]], dtype=float32)>

# %% [markdown]
# ## 1.2 Tensors and NumPy

# %%
a = np.arange(3, dtype=float)
a
# Out:
# array([0., 1., 2.])

# %%
tf.constant(a)
# Out:
# <tf.Tensor: shape=(3,), dtype=float64, numpy=array([0., 1., 2.])>

# %%
t.numpy()
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]], dtype=float32)

# %%
np.asarray(t)
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]], dtype=float32)

# %%
a = np.arange(3, dtype="float32")
a.dtype
# Out:
# dtype('float32')

# %%
tf.constant(a)
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0., 1., 2.], dtype=float32)>

# %% [markdown]
# ## 1.3 Type Conversions

# %%
# tf.constant(2.) + tf.constant(42)

# %%
# tf.constant(2.) + tf.constant(42., dtype=tf.float64)

# %%
tf.constant(2.0) + tf.cast(tf.constant(42.0, dtype=tf.float64), tf.float32)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=44.0>

# %% [markdown]
# ## 1.4 Variables

# %%
v = tf.Variable([[1, 2, 3], [4, 5, 6]], dtype=float)
v
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=float32, numpy=
# array([[1., 2., 3.],
#        [4., 5., 6.]], dtype=float32)>

# %%
w = 2 * v
w
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 2.,  4.,  6.],
#        [ 8., 10., 12.]], dtype=float32)>

# %%
v.assign(2 * v)
# Out:
# <tf.Variable 'UnreadVariable' shape=(2, 3) dtype=float32, numpy=
# array([[ 2.,  4.,  6.],
#        [ 8., 10., 12.]], dtype=float32)>

# %%
v[0, 1].assign(42)
# Out:
# <tf.Variable 'UnreadVariable' shape=(2, 3) dtype=float32, numpy=
# array([[ 2., 42.,  6.],
#        [ 8., 10., 12.]], dtype=float32)>

# %%
v[:, 2].assign([100, 200])
# Out:
# <tf.Variable 'UnreadVariable' shape=(2, 3) dtype=float32, numpy=
# array([[  2.,  42., 100.],
#        [  8.,  10., 200.]], dtype=float32)>

# %%
v.scatter_nd_update(indices=[[0, 0], [1, 2]], updates=[0.1, 0.2])
# Out:
# <tf.Variable 'UnreadVariable' shape=(2, 3) dtype=float32, numpy=
# array([[  0.1,  42. , 100. ],
#        [  8. ,  10. ,   0.2]], dtype=float32)>

# %% [markdown]
# ## 1.5 Other Data Structures
